# %% [markdown]
# ### Anastasia Rizzo

# %% [markdown]
#  ### Data without changed parameters

# %%
# calculate the Pearson's correlation between two variables
from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr
# seed random number generator
seed(1)

# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)

# calculate covariance matrix
covariance = cov(data1, data2)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)

# plot
plt.scatter(data1, data2)
plt.show()

# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearsons correlation: %.3f' % corr)
# Out:
# data1: mean=100.776 stdv=19.620
# data2: mean=151.050 stdv=22.358
# Covariance: 389.755
# Pearsons correlation: 0.888

# %% [markdown]
# ### Task: run and change variables as needed to observe how the change in data points impacts correlation and regression.

# %% [markdown]
#  ### Data with changed parameters

# %%
# calculate the Pearson's correlation between two variables
from numpy import mean
from numpy import std
from numpy import cov
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr
# seed random number generator
seed(1)

# prepare data
data1 = 30 * randn(1000) + 80
data2 = data1 + (20 * randn(1000) + 40)

# calculate covariance matrix
covariance = cov(data1, data2)

# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)

# plot
plt.scatter(data1, data2)
plt.xlabel('Data 1')
plt.ylabel('Data 2')
plt.title('Scatter Plot of Data 1 vs Data 2')
plt.show()

# summarize
print('Summary of Data:')
print('Data 1: mean=%.3f, std=%.3f' % (mean(data1), std(data1)))
print('Data 2: mean=%.3f, std=%.3f' % (mean(data2), std(data2)))
print('Covariance: %.3f' % covariance[0][1])
print('Pearson\'s correlation: %.3f' % corr)

# Conclusion
if corr > 0:
    print('There is a positive correlation between Data 1 and Data 2.')
elif corr < 0:
    print('There is a negative correlation between Data 1 and Data 2.')
else:
    print('There is no significant correlation between Data 1 and Data 2.')
# Out:
# Summary of Data:
# Data 1: mean=81.164, std=29.430
# Data 2: mean=121.711, std=36.291
# Covariance: 880.264
# Pearson's correlation: 0.823
# There is a positive correlation between Data 1 and Data 2.

# %% [markdown]
# **Observation of data:**
#
# Data 1: The mean value is 81.164 with a standard deviation of 29.430.
# Data 2: The mean value is 121.711 with a standard deviation of 36.291.
# Covariance: The calculated covariance is 880.264.
# Pearson's correlation: The computed Pearson's correlation coefficient is 0.823.
#
# **Conclusion:**
# Based on these results, there is a strong positive correlation (0.823) between Data 1 and Data 2. This indicates that as the values in Data 1 increase, the values in Data 2 tend to increase as well. The covariance value of 880.264 further supports this positive relationship between the two variables.The data suggests a significant and positive linear relationship between Data 1 and Data 2.
